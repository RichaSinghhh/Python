# %% [markdown]
# # Pandas Library

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/regression/kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.tail(10)
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21603  7852140040  20140825T000000   507250.0         3       2.50
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21603         2270      5536     2.0           0     0  ...      8
# 21604         1490      1126     3.0           0     0  ...      8
# ...

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.dtypes #to find datatypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.describe() #to find mathemetical values
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df[['id','price','bedrooms','bathrooms']] #to find particular columns and rows data
# Out:
#                id     price  bedrooms  bathrooms
# 0      7129300520  221900.0         3       1.00
# 1      6414100192  538000.0         3       2.25
# 2      5631500400  180000.0         2       1.00
# 3      2487200875  604000.0         4       3.00
# 4      1954400510  510000.0         3       2.00
# ...           ...       ...       ...        ...
# 21608   263000018  360000.0         3       2.50
# 21609  6600060120  400000.0         4       2.50
# 21610  1523300141  402101.0         2       0.75
# 21611   291310100  400000.0         3       2.50
# 21612  1523300157  325000.0         2       0.75
#
# [21613 rows x 4 columns]

# %%
df.dtypes == 'object' #to find object("string")if object then represented true otherwise false.
# Out:
# id               False
# date              True
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df.dtypes == 'float' #if value is flot then we found true otherwise false
# Out:
# id               False
# date             False
# price             True
# bedrooms         False
# bathrooms         True
# sqft_living      False
# sqft_lot         False
# floors            True
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat               True
# long              True
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#           price  bathrooms  floors      lat     long
# 0      221900.0       1.00     1.0  47.5112 -122.257
# 1      538000.0       2.25     2.0  47.7210 -122.319
# 2      180000.0       1.00     1.0  47.7379 -122.233
# 3      604000.0       3.00     1.0  47.5208 -122.393
# 4      510000.0       2.00     1.0  47.6168 -122.045
# ...         ...        ...     ...      ...      ...
# 21608  360000.0       2.50     3.0  47.6993 -122.346
# 21609  400000.0       2.50     2.0  47.5107 -122.362
# 21610  402101.0       0.75     2.0  47.5944 -122.299
# 21611  400000.0       2.50     2.0  47.5345 -122.069
# 21612  325000.0       0.75     2.0  47.5941 -122.299
#
# [21613 rows x 5 columns]

# %%
df[df.dtypes[df.dtypes == 'int64'].index]
# Out:
#                id  bedrooms  sqft_living  sqft_lot  waterfront  view  \
# 0      7129300520         3         1180      5650           0     0
# 1      6414100192         3         2570      7242           0     0
# 2      5631500400         2          770     10000           0     0
# 3      2487200875         4         1960      5000           0     0
# 4      1954400510         3         1680      8080           0     0
# ...           ...       ...          ...       ...         ...   ...
# 21608   263000018         3         1530      1131           0     0
# 21609  6600060120         4         2310      5813           0     0
# 21610  1523300141         2         1020      1350           0     0
# 21611   291310100         3         1600      2388           0     0
# 21612  1523300157         2         1020      1076           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['id'] #to find particular data whatever you want.
# Out:
# 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: id, Length: 21613, dtype: int64

# %%
df[['id']]
# Out:
#                id
# 0      7129300520
# 1      6414100192
# 2      5631500400
# 3      2487200875
# 4      1954400510
# ...           ...
# 21608   263000018
# 21609  6600060120
# 21610  1523300141
# 21611   291310100
# 21612  1523300157
#
# [21613 rows x 1 columns]

# %% [markdown]
# ## Slicing

# %%
df[['id']] [4:16] #to check from where to where in the id,we use this function.
# Out:
#             id
# 4   1954400510
# 5   7237550310
# 6   1321400060
# 7   2008000270
# 8   2414600126
# 9   3793500160
# 10  1736800520
# 11  9212900260
# 12   114101516
# 13  6054650070
# 14  1175000570
# 15  9297300055

# %%
df[['id']] [4:16:2] #Gap
# Out:
#             id
# 4   1954400510
# 6   1321400060
# 8   2414600126
# 10  1736800520
# 12   114101516
# 14  1175000570

# %%
df[['id','price']] #taking two columns together using slicing mathod
# Out:
#                id     price
# 0      7129300520  221900.0
# 1      6414100192  538000.0
# 2      5631500400  180000.0
# 3      2487200875  604000.0
# 4      1954400510  510000.0
# ...           ...       ...
# 21608   263000018  360000.0
# 21609  6600060120  400000.0
# 21610  1523300141  402101.0
# 21611   291310100  400000.0
# 21612  1523300157  325000.0
#
# [21613 rows x 2 columns]

# %%
df[['id','price']] [4:17] #the particular data of two columns is extracted
# Out:
#             id      price
# 4   1954400510   510000.0
# 5   7237550310  1225000.0
# 6   1321400060   257500.0
# 7   2008000270   291850.0
# 8   2414600126   229500.0
# 9   3793500160   323000.0
# 10  1736800520   662500.0
# 11  9212900260   468000.0
# 12   114101516   310000.0
# 13  6054650070   400000.0
# 14  1175000570   530000.0
# 15  9297300055   650000.0
# 16  1875500060   395000.0

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#create new column
df['new_col'] =0

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %%
df['new_col'] =2

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 0             1180      5650     1.0           0     0  ...        1180
# ...

# %%
df['Richa'] =5

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_basement  \
# 0             1180      5650     1.0           0     0  ...              0
# ...

# %%
#add column location according to you
df.insert(loc = 3, column = 'food', value= 0)

# %%
df
# Out:
#                id             date     price  food  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0     0         3       1.00
# 1      6414100192  20141209T000000  538000.0     0         3       2.25
# 2      5631500400  20150225T000000  180000.0     0         2       1.00
# 3      2487200875  20141209T000000  604000.0     0         4       3.00
# 4      1954400510  20150218T000000  510000.0     0         3       2.00
# ...           ...              ...       ...   ...       ...        ...
# 21608   263000018  20140521T000000  360000.0     0         3       2.50
# 21609  6600060120  20150223T000000  400000.0     0         4       2.50
# 21610  1523300141  20140623T000000  402101.0     0         2       0.75
# 21611   291310100  20150116T000000  400000.0     0         3       2.50
# 21612  1523300157  20141015T000000  325000.0     0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# ...

# %%
df.insert(loc = 6,column = 'equipments',value ='Laptop')

# %%
df
# Out:
#                id             date     price  food  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0     0         3       1.00
# 1      6414100192  20141209T000000  538000.0     0         3       2.25
# 2      5631500400  20150225T000000  180000.0     0         2       1.00
# 3      2487200875  20141209T000000  604000.0     0         4       3.00
# 4      1954400510  20150218T000000  510000.0     0         3       2.00
# ...           ...              ...       ...   ...       ...        ...
# 21608   263000018  20140521T000000  360000.0     0         3       2.50
# 21609  6600060120  20150223T000000  400000.0     0         4       2.50
# 21610  1523300141  20140623T000000  402101.0     0         2       0.75
# 21611   291310100  20150116T000000  400000.0     0         3       2.50
# 21612  1523300157  20141015T000000  325000.0     0         2       0.75
#
#       equipments  sqft_living  sqft_lot  floors  ...  sqft_basement  yr_built  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'food', 'bedrooms', 'bathrooms', 'equipments',
#        'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition',
#        'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'new_col',
#        'Richa'],
#       dtype='object')

# %%
df['id']
# Out:
# 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: id, Length: 21613, dtype: int64

# %%
df['id'] [0:10]
# Out:
# 0    7129300520
# 1    6414100192
# 2    5631500400
# 3    2487200875
# 4    1954400510
# 5    7237550310
# 6    1321400060
# 7    2008000270
# 8    2414600126
# 9    3793500160
# Name: id, dtype: int64

# %%
a= df['id'] [0:10]

# %%
a
# Out:
# 0    7129300520
# 1    6414100192
# 2    5631500400
# 3    2487200875
# 4    1954400510
# 5    7237550310
# 6    1321400060
# 7    2008000270
# 8    2414600126
# 9    3793500160
# Name: id, dtype: int64

# %%
l = ['Richa','a2','a3','a4','a5','a6','a7','a8','a9','a10']

# %%
pd.Series(a,index = l)
# Out:
# Richa   NaN
# a2      NaN
# a3      NaN
# a4      NaN
# a5      NaN
# a6      NaN
# a7      NaN
# a8      NaN
# a9      NaN
# a10     NaN
# Name: id, dtype: float64

# %%
pd.Series(list(a),index = l)
# Out:
# Richa    7129300520
# a2       6414100192
# a3       5631500400
# a4       2487200875
# a5       1954400510
# a6       7237550310
# a7       1321400060
# a8       2008000270
# a9       2414600126
# a10      3793500160
# dtype: int64

# %%
m1 = pd.Series([100,200,300,400,500], index = [1,2,3,4,5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600,700,800,900,1000], index = [1,2,3,4,5])

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %% [markdown]
# ### Concatenate function

# %%
m3 = pd.concat([m1,m2])

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]
# Out:
# 1    100
# 1    600
# dtype: int64

# %% [markdown]
# ### Multiply two values

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#            id             date     price  food  bedrooms  bathrooms  \
# 0  7129300520  20141013T000000  221900.0     0         3       1.00
# 1  6414100192  20141209T000000  538000.0     0         3       2.25
# 2  5631500400  20150225T000000  180000.0     0         2       1.00
# 3  2487200875  20141209T000000  604000.0     0         4       3.00
# 4  1954400510  20150218T000000  510000.0     0         3       2.00
#
#   equipments  sqft_living  sqft_lot  floors  ...  sqft_basement  yr_built  \
# 0     Laptop         1180      5650     1.0  ...              0      1955
# 1     Laptop         2570      7242     2.0  ...            400      1951
# 2     Laptop          770     10000     1.0  ...              0      1933
# 3     Laptop         1960      5000     1.0  ...            910      1965
# 4     Laptop         1680      8080     1.0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %% [markdown]
# ### Delete columns

# %%
df.drop("id",axis = 1) #this function used for temporary delete data.
# Out:
#                   date     price  food  bedrooms  bathrooms equipments  \
# 0      20141013T000000  221900.0     0         3       1.00     Laptop
# 1      20141209T000000  538000.0     0         3       2.25     Laptop
# 2      20150225T000000  180000.0     0         2       1.00     Laptop
# 3      20141209T000000  604000.0     0         4       3.00     Laptop
# 4      20150218T000000  510000.0     0         3       2.00     Laptop
# ...                ...       ...   ...       ...        ...        ...
# 21608  20140521T000000  360000.0     0         3       2.50     Laptop
# 21609  20150223T000000  400000.0     0         4       2.50     Laptop
# 21610  20140623T000000  402101.0     0         2       0.75     Laptop
# 21611  20150116T000000  400000.0     0         3       2.50     Laptop
# 21612  20141015T000000  325000.0     0         2       0.75     Laptop
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# ...

# %%
df.head()
# Out:
#            id             date     price  food  bedrooms  bathrooms  \
# 0  7129300520  20141013T000000  221900.0     0         3       1.00
# 1  6414100192  20141209T000000  538000.0     0         3       2.25
# 2  5631500400  20150225T000000  180000.0     0         2       1.00
# 3  2487200875  20141209T000000  604000.0     0         4       3.00
# 4  1954400510  20150218T000000  510000.0     0         3       2.00
#
#   equipments  sqft_living  sqft_lot  floors  ...  sqft_basement  yr_built  \
# 0     Laptop         1180      5650     1.0  ...              0      1955
# 1     Laptop         2570      7242     2.0  ...            400      1951
# 2     Laptop          770     10000     1.0  ...              0      1933
# 3     Laptop         1960      5000     1.0  ...            910      1965
# 4     Laptop         1680      8080     1.0  ...              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# ...

# %%
df.drop("date",axis =1)
# Out:
#                id     price  food  bedrooms  bathrooms equipments  \
# 0      7129300520  221900.0     0         3       1.00     Laptop
# 1      6414100192  538000.0     0         3       2.25     Laptop
# 2      5631500400  180000.0     0         2       1.00     Laptop
# 3      2487200875  604000.0     0         4       3.00     Laptop
# 4      1954400510  510000.0     0         3       2.00     Laptop
# ...           ...       ...   ...       ...        ...        ...
# 21608   263000018  360000.0     0         3       2.50     Laptop
# 21609  6600060120  400000.0     0         4       2.50     Laptop
# 21610  1523300141  402101.0     0         2       0.75     Laptop
# 21611   291310100  400000.0     0         3       2.50     Laptop
# 21612  1523300157  325000.0     0         2       0.75     Laptop
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# 0             1180      5650     1.0           0  ...              0
# ...

# %%
#this function used for permanently delete data.
df.drop("date",axis =1,inplace = True)

# %%
df
# Out:
#                id     price  food  bedrooms  bathrooms equipments  \
# 0      7129300520  221900.0     0         3       1.00     Laptop
# 1      6414100192  538000.0     0         3       2.25     Laptop
# 2      5631500400  180000.0     0         2       1.00     Laptop
# 3      2487200875  604000.0     0         4       3.00     Laptop
# 4      1954400510  510000.0     0         3       2.00     Laptop
# ...           ...       ...   ...       ...        ...        ...
# 21608   263000018  360000.0     0         3       2.50     Laptop
# 21609  6600060120  400000.0     0         4       2.50     Laptop
# 21610  1523300141  402101.0     0         2       0.75     Laptop
# 21611   291310100  400000.0     0         3       2.50     Laptop
# 21612  1523300157  325000.0     0         2       0.75     Laptop
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# 0             1180      5650     1.0           0  ...              0
# ...

# %% [markdown]
# ### Delete Rows

# %%
df.drop(3) #this function used for temporary delete data.
# Out:
#                id      price  food  bedrooms  bathrooms equipments  \
# 0      7129300520   221900.0     0         3       1.00     Laptop
# 1      6414100192   538000.0     0         3       2.25     Laptop
# 2      5631500400   180000.0     0         2       1.00     Laptop
# 4      1954400510   510000.0     0         3       2.00     Laptop
# 5      7237550310  1225000.0     0         4       4.50     Laptop
# ...           ...        ...   ...       ...        ...        ...
# 21608   263000018   360000.0     0         3       2.50     Laptop
# 21609  6600060120   400000.0     0         4       2.50     Laptop
# 21610  1523300141   402101.0     0         2       0.75     Laptop
# 21611   291310100   400000.0     0         3       2.50     Laptop
# 21612  1523300157   325000.0     0         2       0.75     Laptop
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# 0             1180      5650     1.0           0  ...              0
# ...

# %%
df.head()
# Out:
#            id     price  food  bedrooms  bathrooms equipments  sqft_living  \
# 0  7129300520  221900.0     0         3       1.00     Laptop         1180
# 1  6414100192  538000.0     0         3       2.25     Laptop         2570
# 2  5631500400  180000.0     0         2       1.00     Laptop          770
# 3  2487200875  604000.0     0         4       3.00     Laptop         1960
# 4  1954400510  510000.0     0         3       2.00     Laptop         1680
#
#    sqft_lot  floors  waterfront  ...  sqft_basement  yr_built  yr_renovated  \
# 0      5650     1.0           0  ...              0      1955             0
# 1      7242     2.0           0  ...            400      1951          1991
# 2     10000     1.0           0  ...              0      1933             0
# 3      5000     1.0           0  ...            910      1965             0
# 4      8080     1.0           0  ...              0      1987             0
#
# ...

# %%
df.drop(3,inplace =True ) #this function used for permanently delete data.

# %%
df
# Out:
#                id      price  food  bedrooms  bathrooms equipments  \
# 0      7129300520   221900.0     0         3       1.00     Laptop
# 1      6414100192   538000.0     0         3       2.25     Laptop
# 2      5631500400   180000.0     0         2       1.00     Laptop
# 4      1954400510   510000.0     0         3       2.00     Laptop
# 5      7237550310  1225000.0     0         4       4.50     Laptop
# ...           ...        ...   ...       ...        ...        ...
# 21608   263000018   360000.0     0         3       2.50     Laptop
# 21609  6600060120   400000.0     0         4       2.50     Laptop
# 21610  1523300141   402101.0     0         2       0.75     Laptop
# 21611   291310100   400000.0     0         3       2.50     Laptop
# 21612  1523300157   325000.0     0         2       0.75     Laptop
#
#        sqft_living  sqft_lot  floors  waterfront  ...  sqft_basement  \
# 0             1180      5650     1.0           0  ...              0
# ...

# %% [markdown]
# ### ek particular column ko
