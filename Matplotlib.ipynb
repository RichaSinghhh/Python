# %% [markdown]
# ### Matplotlib Library

# %% [markdown]
# ### Plots
# - Linear Plot
# - Scatter Plot
# - Bar Plot
# - Stem Plot
# - step Plot
# - Hist Plot
# - Box Plot
# - Pie Plot
# - Fill_Between_Plot

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Linear Graph

# %%
x = [1,2,3,4]
y = [5,6,7,8]
plt.plot(x,y)

# %%
x = [1,2,3,4]
y = [5,6,7,8]
c = 'r'
plt.plot(x,y,c)
plt.show()
